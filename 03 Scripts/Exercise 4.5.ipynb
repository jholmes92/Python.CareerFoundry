# %% [markdown]
# # Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
df_prods = pd.read_csv(r"C:\Users\repla\Documents\02 Data\Original Data\products.csv", index_col = False)

# %%
df_ords = pd.read_csv(r"C:\Users\repla\Documents\02 Data\Prepared Data\orders_wrangled.csv", index_col = False)

# %% [markdown]
# # Exercise

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  time_of_order  days_since_prior_order
# count        3.421083e+06   3.421083e+06            3.214874e+06
# mean         2.776219e+00   1.345202e+01            1.111484e+01
# std          2.046829e+00   4.226088e+00            9.206737e+00
# min          0.000000e+00   0.000000e+00            0.000000e+00
# 25%          1.000000e+00   1.000000e+01            4.000000e+00
# ...

# %%
#Create a dataframe
df_test = pd.DataFrame()

# %%
#Create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed data types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# C:\Users\repla\AppData\Local\Temp\ipykernel_61852\1737234719.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %%
#Finding missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
#create new data frame with the missing values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# Comparison 
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#drop all missing values
df_prods.dropna(inplace = True)

# %%
df_prods.dropna(subset = ['product_name'], inplace = True)

# %%
#searching for duplicates
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
#addressing duplicates
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
#rename dataframe
path =r"C:\Users\repla\Documents"

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # Task

# %%
#2
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  time_of_order  days_since_prior_order
# count        3.421083e+06   3.421083e+06            3.214874e+06
# mean         2.776219e+00   1.345202e+01            1.111484e+01
# std          2.046829e+00   4.226088e+00            9.206737e+00
# min          0.000000e+00   0.000000e+00            0.000000e+00
# 25%          1.000000e+00   1.000000e+01            4.000000e+00
# ...

# %%
# I think the STD of days_since_prior_order seems a little high. Also, the unnamed & order_id colums are identical. Also, the count row is identical for all but 'days_since_prior_order'

# %%
#3
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_61852\3201197653.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\repla\AppData\Local\Temp\ipykernel_61852\3201197653.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\repla\AppData\Local\Temp\ipykernel_61852\3201197653.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\repla\AppData\Local\Temp\ipykernel_61852\3201197653.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
#4
df_ords['Unnamed: 0'] = df_ords['Unnamed: 0'].astype('str')

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        time_of_order  days_since_prior_order
# count   3.421083e+06            3.214874e+06
# mean    1.345202e+01            1.111484e+01
# std     4.226088e+00            9.206737e+00
# min     0.000000e+00            0.000000e+00
# 25%     1.000000e+01            4.000000e+00
# 50%     1.300000e+01            7.000000e+00
# ...

# %%
#5
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# orders_day_of_week             0
# time_of_order                  0
# days_since_prior_order    206209
# dtype: int64

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
#3214874 rows HAVE input in the 'days_since_prior_order' column. This information could have been received as null, therefore providing no information at this time.

# %%
#6
df_none = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_none
# Out:
#         Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                0   2539329        1             1                   2
# 11              11   2168274        2             1                   2
# 26              26   1374495        3             1                   1
# 39              39   3343014        4             1                   6
# 45              45   2717275        5             1                   3
# ...            ...       ...      ...           ...                 ...
# 3420930    3420930    969311   206205             1                   4
# 3420934    3420934   3189322   206206             1                   3
# 3421002    3421002   2166133   206207             1                   6
# 3421019    3421019   2227043   206208             1                   1
# 3421069    3421069   3154581   206209             1                   3
#
#          time_of_order  days_since_prior_order
# 0                    8                     NaN
# ...

# %%
df_none['days_since_prior_order'].fillna(1, inplace=True)
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_61852\2859434468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_none['days_since_prior_order'].fillna(1, inplace=True)

# %%
df_none.shape
# Out:
# (206209, 7)

# %%
df_none.isnull().sum()
# Out:
# Unnamed: 0                0
# order_id                  0
# user_id                   0
# order_number              0
# orders_day_of_week        0
# time_of_order             0
# days_since_prior_order    0
# dtype: int64

# %%
#I replaced all of the null values with the mean '1'

# %%
#7
df_no_dups = df_none[df_none.duplicated()]

# %%
df_no_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, orders_day_of_week, time_of_order, days_since_prior_order]
# Index: []

# %%
#I found there to be no duplicate values in the dataframe

# %%
#8 - No douplicates to address

# %%
#9
df_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_checked.csv'))

# %%
#i did this step for df_prods right before the 'Task' header

# %%
# ---

# %%
df_ords = pd.read_csv(r"C:\Users\repla\Documents\02 Data\Prepared Data\orders_checked.csv", index_col = False)

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
df_ords
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, order_id, user_id, order_number, orders_day_of_week, time_of_order, days_since_prior_order]
# Index: []

# %%
df_ords = pd.read_csv(r"C:\Users\repla\Documents\02 Data\Prepared Data\orders_wrangled.csv", index_col = False)

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 1   2398795        1             2                   3
# 2                 2    473747        1             3                   3
# 3                 3   2254736        1             4                   4
# 4                 4    431534        1             5                   4
# ...             ...       ...      ...           ...                 ...
# 3421078     3421078   2266710   206209            10                   5
# 3421079     3421079   1854736   206209            11                   4
# 3421080     3421080    626363   206209            12                   1
# 3421081     3421081   2977660   206209            13                   1
# 3421082     3421082    272231   206209            14                   6
#
#          time_of_order  days_since_prior_order
# ...

# %%
#3
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_93852\3201197653.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\repla\AppData\Local\Temp\ipykernel_93852\3201197653.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\repla\AppData\Local\Temp\ipykernel_93852\3201197653.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\repla\AppData\Local\Temp\ipykernel_93852\3201197653.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
#4
df_ords['Unnamed: 0'] = df_ords['Unnamed: 0'].astype('str')

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        time_of_order  days_since_prior_order
# count   3.421083e+06            3.214874e+06
# mean    1.345202e+01            1.111484e+01
# std     4.226088e+00            9.206737e+00
# min     0.000000e+00            0.000000e+00
# 25%     1.000000e+01            4.000000e+00
# 50%     1.300000e+01            7.000000e+00
# ...

# %%
#5
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# orders_day_of_week             0
# time_of_order                  0
# days_since_prior_order    206209
# dtype: int64

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
#6
df_none = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_none
# Out:
#         Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                0   2539329        1             1                   2
# 11              11   2168274        2             1                   2
# 26              26   1374495        3             1                   1
# 39              39   3343014        4             1                   6
# 45              45   2717275        5             1                   3
# ...            ...       ...      ...           ...                 ...
# 3420930    3420930    969311   206205             1                   4
# 3420934    3420934   3189322   206206             1                   3
# 3421002    3421002   2166133   206207             1                   6
# 3421019    3421019   2227043   206208             1                   1
# 3421069    3421069   3154581   206209             1                   3
#
#          time_of_order  days_since_prior_order
# 0                    8                     NaN
# ...

# %%
df_none['days_since_prior_order'].fillna(0, inplace=True)
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_93852\3303484663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_none['days_since_prior_order'].fillna(0, inplace=True)

# %%
df_none.shape
# Out:
# (206209, 7)

# %%
df_none.isnull().sum()
# Out:
# Unnamed: 0                0
# order_id                  0
# user_id                   0
# order_number              0
# orders_day_of_week        0
# time_of_order             0
# days_since_prior_order    0
# dtype: int64

# %%
#7
df_no_dups = df_none[df_none.duplicated()]

# %%
df_no_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, orders_day_of_week, time_of_order, days_since_prior_order]
# Index: []

# %%
df_none
# Out:
#         Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                0   2539329        1             1                   2
# 11              11   2168274        2             1                   2
# 26              26   1374495        3             1                   1
# 39              39   3343014        4             1                   6
# 45              45   2717275        5             1                   3
# ...            ...       ...      ...           ...                 ...
# 3420930    3420930    969311   206205             1                   4
# 3420934    3420934   3189322   206206             1                   3
# 3421002    3421002   2166133   206207             1                   6
# 3421019    3421019   2227043   206208             1                   1
# 3421069    3421069   3154581   206209             1                   3
#
#          time_of_order  days_since_prior_order
# 0                    8                     0.0
# ...

# %%
df_ords_no_dups = df_ords.drop_duplicates()

# %%
df_ords_no_dups
# Out:
#         Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                0   2539329        1             1                   2
# 1                1   2398795        1             2                   3
# 2                2    473747        1             3                   3
# 3                3   2254736        1             4                   4
# 4                4    431534        1             5                   4
# ...            ...       ...      ...           ...                 ...
# 3421078    3421078   2266710   206209            10                   5
# 3421079    3421079   1854736   206209            11                   4
# 3421080    3421080    626363   206209            12                   1
# 3421081    3421081   2977660   206209            13                   1
# 3421082    3421082    272231   206209            14                   6
#
#          time_of_order  days_since_prior_order
# 0                    8                     NaN
# ...

# %%
df_ords_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_checkedCORRECT.csv'))

# %%
# define path
path =r"C:\Users\repla\Documents"
