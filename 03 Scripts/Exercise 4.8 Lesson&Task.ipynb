# %% [markdown]
# # Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# define path
path =r"C:\Users\repla\Documents"

# %%
#Import most recent orders_products_merged pickle 
ords_prods_merge = pd.read_pickle(r"C:\Users\repla\Documents\02 Data\Prepared Data\orders_products_merged4.7.pkl")

# %%
# create a subset of the data
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0   3139998      138            28                   6             11
# ...

# %% [markdown]
# # Grouping Data with Pandas

# %%
df.groupby('product_name')

# %% [markdown]
# # Aggregating Data with agg()

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
#performing multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# # Aggregating Data with transform()

# %%
df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\3693603773.py:1: FutureWarning: The provided callable <function amax at 0x000001D9F0A51BC0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\3693603773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
pd.options.display.max_rows = None

# %% [markdown]
# # Deriving Columns with loc()

# %%
#adding loyalty flag
df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\3226195648.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\3226195648.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    473070
# Loyal customer      287917
# New customer        239013
# Name: count, dtype: int64

# %%
df['column']

# %%
df[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494      New customer             6
# 15     1494      New customer             7
# 16     1494      New customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...

# %% [markdown]
# # Task

# %%
#2
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
#3 - I do not see any difference between the two dataframes (ords_prods_merge & df)

# %%
#4 - Completed in outputs 18-24

# %%
#5
df.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.674593  1.0  24.5
# New customer      7.792591  1.0  24.5
# Regular customer  7.750368  1.0  24.5

# %%
#6
df['average_price'] = df.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\4286559675.py:2: FutureWarning: The provided callable <function mean at 0x000001D9F0A528E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df['average_price'] = df.groupby(['user_id'])['prices'].transform(np.mean)
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\4286559675.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average_price'] = df.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  ...  \
# 0   3139998      138            28                   6             11  ...
# 1   1977647      138            30                   6             17  ...
# 2    389851      709             2                   0             21  ...
# 3    652770      764             1                   3             13  ...
# 4   1813452      764             3                   4             17  ...
#
# ...

# %%
df.loc[df['average_price'] < 10, 'spending_flag'] = 'Low spender'
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\1507961159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['average_price'] < 10, 'spending_flag'] = 'Low spender'
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\1507961159.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low spender' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df.loc[df['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     805506
# High spender    194494
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  ...  \
# 0   3139998      138            28                   6             11  ...
# 1   1977647      138            30                   6             17  ...
# 2    389851      709             2                   0             21  ...
# 3    652770      764             1                   3             13  ...
# 4   1813452      764             3                   4             17  ...
#
# ...

# %%
#7
df['median_orders'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\1358387830.py:2: FutureWarning: The provided callable <function median at 0x000001D9F0B93880> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df['median_orders'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\1358387830.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['median_orders'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  ...  \
# 0   3139998      138            28                   6             11  ...
# 1   1977647      138            30                   6             17  ...
# 2    389851      709             2                   0             21  ...
# 3    652770      764             1                   3             13  ...
# 4   1813452      764             3                   4             17  ...
#
# ...

# %%
df.loc[df['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\1265179914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
# C:\Users\repla\AppData\Local\Temp\ipykernel_32336\1265179914.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df.loc[(df['median_orders'] > 10) & (df['median_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
df.loc[df['median_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        641346
# Regular customer         221585
# Non-frequent customer    128877
# NaN                        8192
# Name: count, dtype: int64

# %%
#9
df.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged4.8.pkl'))
